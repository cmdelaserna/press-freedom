# %% [markdown]
# # Exploring ACLED data

# %%
# African dataset
# https://www.acleddata.com/curated-data-files/

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_excel('../data/Africa_1997-2019_Oct12-1.xlsx')

# %% [markdown]
# ## Data exploration

# %%
df.sample(5)
# Out:
#         ISO EVENT_ID_CNTY  EVENT_ID_NO_CNTY EVENT_DATE  YEAR  TIME_PRECISION  \
# 43826   231       ETH1209              1209 2008-12-15  2008               1
# 77019   504       MOR2210              2210 2019-10-03  2019               1
# 168322  748        SWA213               213 2019-09-23  2019               1
# 51517   384        CDI833               833 2010-02-20  2010               1
# 69983   450        MAG542               542 2014-05-08  2014               2
#
#                         EVENT_TYPE    SUB_EVENT_TYPE  \
# 43826   Violence against civilians            Attack
# 77019                     Protests  Peaceful protest
# 168322                    Protests  Peaceful protest
# 51517                     Protests  Peaceful protest
# 69983                      Battles       Armed clash
#
#                                          ACTOR1              ASSOC_ACTOR_1  \
# 43826   Military Forces of Ethiopia (1995-2018)                        NaN
# 77019                      Protesters (Morocco)     Labour Group (Morocco)
# 168322                    Protesters (eSwatini)                        NaN
# 51517                  Protesters (Ivory Coast)                        NaN
# 69983                            Dahalo Militia  Pastoralists (Madagascar)
#
#            ...           ADMIN3 LOCATION LATITUDE  LONGITUDE  GEO_PRECISION  \
# 43826      ...          Gashamo   Somali    8.000     45.000              2
# 77019      ...      NA (Agadir)   Agadir   30.420     -9.598              1
# 168322     ...              NaN  Mbabane  -26.317     31.133              1
# 51517      ...           Gagnoa   Gagnoa    6.132     -5.951              1
# 69983      ...              NaN  Betroka  -23.357     45.936              1
#
#                                 SOURCE   SOURCE_SCALE  \
# 43826                    Sudan Tribune       National
# 77019                         Agadir24    Subnational
# 168322            Times (South Africa)       National
# 51517                          Reuters  International
# 69983   RFI; Business Standard (India)       National
#
#                                                     NOTES FATALITIES  \
# 43826   Village of Galashe, ONLF claim that the govern...          0
# 77019   On 3 October 2019, artists held a protest in f...          0
# 168322  23 September. 3500 Demonstrators marched in Mb...          0
# 51517   Protests after Gbagbo dissolves government and...          0
# 69983   Conflict between Dahalo cattle rustlers, villa...          4
#
#          TIMESTAMP
# 43826   1567462283
# 77019   1570483478
# 168322  1570482728
# 51517   1561469023
# 69983   1568053753
#
# [5 rows x 29 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 193565 entries, 0 to 193564
# Data columns (total 29 columns):
# ISO                 193565 non-null int64
# EVENT_ID_CNTY       193565 non-null object
# EVENT_ID_NO_CNTY    193565 non-null int64
# EVENT_DATE          193565 non-null datetime64[ns]
# YEAR                193565 non-null int64
# TIME_PRECISION      193565 non-null int64
# EVENT_TYPE          193565 non-null object
# SUB_EVENT_TYPE      193565 non-null object
# ACTOR1              193565 non-null object
# ASSOC_ACTOR_1       40873 non-null object
# INTER1              193565 non-null int64
# ACTOR2              145938 non-null object
# ASSOC_ACTOR_2       31268 non-null object
# INTER2              193565 non-null int64
# INTERACTION         193565 non-null int64
# REGION              193565 non-null object
# COUNTRY             193565 non-null object
# ADMIN1              193565 non-null object
# ADMIN2              193440 non-null object
# ADMIN3              99660 non-null object
# LOCATION            193565 non-null object
# LATITUDE            193565 non-null float64
# LONGITUDE           193565 non-null float64
# GEO_PRECISION       193565 non-null int64
# SOURCE              193565 non-null object
# SOURCE_SCALE        193565 non-null object
# NOTES               184245 non-null object
# FATALITIES          193565 non-null int64
# TIMESTAMP           193565 non-null int64
# dtypes: datetime64[ns](1), float64(2), int64(10), object(16)
# memory usage: 42.8+ MB

# %%
print('Event types: {}\n'.format(df['EVENT_TYPE'].unique()))
print('Event subtypes: {}'.format(df['SUB_EVENT_TYPE'].unique()))
# Out:
# Event types: ['Violence against civilians' 'Battles' 'Explosions/Remote violence'
#  'Protests' 'Strategic developments' 'Riots']
#
# Event subtypes: ['Attack' 'Armed clash' 'Remote explosive/landmine/IED'
#  'Shelling/artillery/missile attack' 'Peaceful protest'
#  'Change to group/activity' 'Looting/property destruction'
#  'Government regains territory' 'Disrupted weapons use'
#  'Protest with intervention' 'Violent demonstration' 'Mob violence'
#  'Air/drone strike' 'Other' 'Arrests' 'Excessive force against protesters'
#  'Abduction/forced disappearance' 'Suicide bomb' 'Grenade'
#  'Non-violent transfer of territory' 'Headquarters or base established'
#  'Agreement' 'Non-state actor overtakes territory' 'Sexual violence'
#  'Chemical weapon']

# %%
# Plotting time series
# https://www.kaggle.com/lordkada/acled-simple-analysis

event_type = df.groupby(['EVENT_DATE'])['EVENT_TYPE'].count()
event_type.plot(subplots=True, figsize=(20, 10), style='.', alpha=0.5)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x118221978>],
#       dtype=object)

# %%
year = df.groupby(['YEAR'])['EVENT_TYPE'].count()
year.plot(kind='bar', color = 'gray', figsize=(20, 10))

# %%
country = df.groupby(['COUNTRY'])['EVENT_TYPE'].count()
country.plot(kind='bar', color = 'gray', figsize=(20, 10))
